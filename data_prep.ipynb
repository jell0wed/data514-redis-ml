# %%
import pandas as pd

# %%
test_df = pd.read_csv("data/test.csv")
test_df_labels = pd.read_csv("data/test_labels.csv")

# merge both datasets
test_df = pd.merge(test_df, test_df_labels, on='id', how='inner')
test_df = test_df[['id', 'comment_text', 'toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']]
test_df.loc[(test_df['obscene'] == 1) & (test_df['toxic'] == 0)]
# Out:
#                       id                                       comment_text  \
# 1940    0354cef5d6b07504               , Im a bit of a grumpy fuck just now
# 7935    0d5305657328ba92                              BOOBS   AwesomeSauce.
# 14092   17b2fad0ea012a40  " \n\n - \n Hey, you just welcomed yourself. T...
# 16529   1bd0cf5bd19f1bac                Du bist ein geistesgestörter Idiot!
# 16722   1c240b86594e5d20  escuchar tu voz y me sonroje al oir tu te quie...
# ...                  ...                                                ...
# 142108  ed8c7b4f4b5c38eb  " \n :::Damn, I hate to see you leave. But, if...
# 146358  f4a260697ecc1035  I am only deleting pages, because some idiot h...
# 148517  f83635552aaed1fd                         ^ dam u str8 babygurl itc.
# 149916  fa9353bea43db289  " \n * I DID I DID!!! That was awesome i was i...
# 152018  fe0631617822259f  " \n\n == grunge bands == \n\n add Willard ""T...
#
#         toxic  severe_toxic  obscene  threat  insult  identity_hate
# 1940        0             0        1       0       0              0
# 7935        0             0        1       0       0              0
# 14092       0             0        1       0       0              0
# 16529       0             0        1       0       1              0
# 16722       0             0        1       0       0              0
# ...       ...           ...      ...     ...     ...            ...
# 142108      0             0        1       0       0              0
# 146358      0             0        1       0       0              0
# 148517      0             0        1       0       0              0
# 149916      0             0        1       0       0              0
# 152018      0             0        1       0       0              0
#
# [65 rows x 8 columns]
